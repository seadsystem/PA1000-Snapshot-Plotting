# %%
run ./snapshot_t.py
# Out:
# {'device1': {'on': set(['current', 'voltage', 'wattege'])}}
# ...

# %%
# Out:
# hello world

# %%
run ./snapshot_t.py

# %%
run ./snapshot.py /home/seads/SEADS-Projects/SnapshotData/Computer_1_Monitor_1_ON.csv
