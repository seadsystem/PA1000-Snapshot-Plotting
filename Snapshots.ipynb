# %%
run ./plotall.py
# Out:
# TV_SHARP_46_ON.csv
# Monitor_1_ON.csv
# Computer_2_on.csv
# Computer_1_on.csv
# Refrigerator_1_Defrust_ON.csv
# Refrigerator_1_Norm_ON.csv

# %%
# Out:
# hello world

# %%
run ./snapshot_t.py

# %%
run ./snapshot.py /home/seads/SEADS-Projects/SnapshotData/Computer_1_Monitor_1_ON.csv
